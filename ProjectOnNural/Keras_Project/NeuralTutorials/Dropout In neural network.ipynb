# %% [markdown]
# #### Dropout (regularization technique prevent overfitting)
#
# Dropout randomly deactivates neurons during training to prevent overfitting, improve generalization, and boost accuracy. - Dropout is a surprisingly effective regularization technique where neurons are randomly "dropped" during training.
#
# - Even state-of-the-art models saw a 1–2% accuracy boost with dropout. For example, improving accuracy from 95% to 97% reduces error rate by ~40% (from 5% to ~3%).
#
# - How it works:
#     - At each training step, every neuron (except output neurons) has a probability $p$ of being “dropped out.”
#     - Dropped neurons are ignored for that step but may be active in the next.
#     - Typical dropout rate: $50$%.
#     - After training: Dropout is disabled, and all neurons are used for inference.
#
# ![image.png](attachment:image.png)
#
# ## Dropout in Neural Networks
#
# - **Dropout** is a regularization technique where neurons are randomly "dropped" during training.
# - This forces the network to become **resilient and decentralized**, similar to a company where employees randomly skip work.
# - Neurons cannot **co-adapt** or rely heavily on specific inputs, making them individually robust.
# - Each training step effectively creates a **unique sub-network**, leading to an ensemble of thousands of slightly different models.
# - The final model behaves like an **average of these networks**, improving generalization.
# - **Technical detail:** During testing, weights must be scaled by the **keep probability** (e.g., 0.5 if dropout rate is 50%) to match the expected input signal from training.
#
# #### Mathematical Formulation of Dropout:
#
# Pobability of neural network
#
# let $X$ = Input vector
#
# $W$  = Weight vector
#
# $b$ = biased term
#
# So $z$ = $X*W + b$
#
# ![image-2.png](attachment:image-2.png)
#
# Suppose we have a hidden layer with input vector \mathbf{h} and weight matrix W.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# #### Explain Monte-Carlo (MC) Dropout & how it is different from dropout?
#
# Monte Carlo (MC) Dropout is an **extension of standard dropout** where dropout is also applied at test time (inference), not just during training. This allows the model to generate **multiple stochastic predictions** for the same input, which can be averaged to improve accuracy and used to estimate uncertainty. Standard dropout, by contrast, is only used during training as a regularization method.
#
# - Purpose: Regularization to prevent overfitting
#
# TODO Math’s behind MC Dropout & Besic difference from standards dropout method
